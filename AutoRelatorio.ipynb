# %%
import pyautogui
import time 
import pyperclip


pyautogui.PAUSE = 1

# %%
#abrir navegador
pyautogui.press("winleft")
pyautogui.write("chorme")
pyautogui.press("enter")
pyautogui.alert("Vai começar, aperte OK e não mexa mais no nootbok") #este método cria um alerta na tela
pyautogui.hotkey('ctrl', 't') #este método executa um atalho do teclado

# %%
#abrir driver 
link = "https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing"
#utilizamos uma variável para armazenar o link, pois o python não iterpreta caracteres especiais
pyperclip.copy(link)
pyautogui.hotkey('ctrl','v')
pyautogui.press("enter")
time.sleep(5)

# %%
#célula para método position()
#time.sleep(6)
#pyautogui.position()

# %%
#baixar base de banco de dados
pyautogui.click(435, 340, clicks=2)#entrando na pasta
pyautogui.click(447,457)#click no arquivo
pyautogui.click(1670,187)#click três bolinhas
pyautogui.click(1374,703)#click fazer download
time.sleep(10)

# %%
#importando base de dados 
import pandas as pd

df = pd.read_excel(r'C:\Users\bgued\Downloads\Vendas - Dez.xlsx')#Variável para armaenar o local da base 
display(df)#exibir a base
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
#calculando indicadores

faturamento = df['Valor Final'].sum()
qtde_produtos = df['Quantidade'].sum()

# %%
#Criando um relatório de email

#abrir aba do eamil
pyautogui.hotkey('ctrl','t')
pyautogui.write("mail.google.com")
pyautogui.press("enter")
time.sleep(5)

#escrever email
pyautogui.click(120,206)
pyautogui.write('guedesbarroco@gmail.com')
pyautogui.press('tab')
pyautogui.press('tab')
assunto = "Relatório de Vendas"
pyperclip.copy(assunto)
pyautogui.hotkey('ctrl','v')
pyautogui.press('tab')
texto = f"""
    Prezados, boa tarde
    
    O faturamento de ontem foi de: R${faturamento: ,.2f}
    A quantidade de produtos de: {qtde_produtos: ,}
        
    Abs,
    Arthur Guedes"""
pyperclip.copy(texto)
pyautogui.hotkey('ctrl','v')
pyautogui.hotkey('ctrl','enter')
